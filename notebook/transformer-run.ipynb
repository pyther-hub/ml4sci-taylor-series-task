# %%
# !git clone https://github.com/pyther-hub/ml4sci-taylor-series-task.git
# Out:
# Cloning into 'ml4sci-taylor-series-task'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 77 (delta 39), reused 58 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (77/77), 351.74 KiB | 7.99 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# %cd /kaggle/working/ml4sci-taylor-series-task
# Out:
# /kaggle/working/ml4sci-taylor-series-task

# %%
"""
main.py
==================
Training entry point for the unified Taylor coefficient prediction pipeline.

The model predicts ALL five Taylor coefficients in a single pass, using
<BREAK> tokens to delimit individual coefficients in the output sequence.

Training loop only computes teacher-forced val loss (fast).  After training,
loads best checkpoint, runs greedy decoding, and computes full accuracy metrics.

Usage
-----
python main.py

Edit the hyperparameters in the config section below.
"""

from __future__ import annotations

import os
import time
from typing import Dict

import torch
import torch.nn as nn

from dataset import BREAK_ID, EOS_ID, N_COEFFS, PAD_ID, SOS_ID, VOCAB_SIZE, decode, encode
from model import CoeffPredLSTM, CoeffPredTransformer
from train_validate import (
    build_dataloaders,
    get_device,
    print_epoch,
    set_seed,
    train_epoch,
    validate,
)

# ── Evaluation helpers ────────────────────────────────────────────────────
import sympy as sp
from dataset_generation import (
    _expr_to_prefix_tokens,
    compute_taylor_coefficients,
    prefix_tokens_to_infix,
)
from metrics import split_segments, per_segment_metrics

from report_logger import ReportLogger, sympy_equiv

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CUSTOM TEST FUNCTIONS
# ══════════════════════════════════════════════════════════════════════════════

CUSTOM_TEST_FUNCTIONS = [
    "(x**2 + 1)*sin(x)",
    "x**3*cos(2*x)",
    "exp(x)*(1 + x)",
    "x*exp(2*x)",
    "(1 + x**2)*exp(-x)",
    "exp(x)*sin(x)",
    "log(1 + x)",
    "log(1 + x**2)",
    "x*log(1 + x)",
    "x/(1 - x)",
    "x/(1 + x)",
    "1/(1 + x**2)",
    "x**2/(1 - x)",
    "sin(x**2)",
    "exp(x**2)",
    "cos(sqrt(1 + x))",
    "log(1 + sin(x))",
    "(x + 1)*exp(x)",
    "x**2*log(1 + x)",
    "exp(x)*cos(x)",
    "exp(x)*(x**2 + 1)",
    "sin(x)*cos(x)",
    "log(1 + x**3)",
    "log(1 + x)*cos(x)",
    "x*exp(x)*sin(x)",
    "x*exp(x)*cos(x)",
    "sqrt(1 + x)*sin(x)",
    "sqrt(1 + x)/(1 + x)",
    "cos(x)/(1 + x)",
    "exp(x)/(1 + x)",
]

TAYLOR_ORDER = N_COEFFS - 1   # 4 → coefficients c0 … c4
x_sym        = sp.Symbol("x")


# ══════════════════════════════════════════════════════════════════════════════
# HELPERS
# ══════════════════════════════════════════════════════════════════════════════

MODEL_CLASSES = {
    "transformer": CoeffPredTransformer,
    "lstm":        CoeffPredLSTM,
}

def build_model(model_type: str, config: Dict) -> nn.Module:
    """Instantiate the correct model class from model_type and config dict."""
    cls = MODEL_CLASSES[model_type]
    return cls(**config)


def run_custom_test_functions(
    model:   nn.Module,
    device:  torch.device,
    logger:  ReportLogger | None = None,
    max_gen_len: int = 512,
) -> tuple[int, int, int]:
    """Run evaluation on CUSTOM_TEST_FUNCTIONS with exact-match + SymPy equivalence.

    Returns (n_exact_correct, n_sympy_correct, n_attempted).
    """
    n_fn_exact   = 0
    n_fn_sympy   = 0
    n_fn_attempted = 0

    model.eval()
    with torch.no_grad():
        for fn_idx, fn_str in enumerate(CUSTOM_TEST_FUNCTIONS, 1):
            # 1. Parse string → sympy
            try:
                expr = sp.sympify(fn_str, locals={"x": x_sym})
            except Exception as e:
                print(f"\n  [{fn_idx:2d}] {fn_str}")
                print(f"       PARSE ERROR: {e}")
                continue

            # 2. Ground-truth Taylor coefficients
            gt_coeffs = compute_taylor_coefficients(expr, TAYLOR_ORDER)
            if gt_coeffs is None:
                print(f"\n  [{fn_idx:2d}] {fn_str}")
                print(f"       COEFF ERROR: sympy timed out")
                continue

            gt_token_lists = [_expr_to_prefix_tokens(c) for c in gt_coeffs]

            # 3. Encode source sequence
            fn_prefix = _expr_to_prefix_tokens(expr)
            src_ids   = [SOS_ID] + encode(fn_prefix) + [EOS_ID]
            src       = torch.tensor([src_ids], dtype=torch.long).to(device)

            # 4. Autoregressive decoding
            pred_ids = model.generate(src, max_len=max_gen_len)

            # 5. Split prediction on <BREAK> into per-coefficient segments
            pred_segs = split_segments(pred_ids, BREAK_ID, EOS_ID, PAD_ID)

            # 6. Compare: exact match + SymPy equivalence
            n_fn_attempted += 1
            n_coeff_exact = 0
            n_coeff_sympy = 0
            coeff_results = []

            print(f"\n  [{fn_idx:2d}] f(x) = {fn_str}")
            for coeff_i in range(N_COEFFS):
                gt_toks   = gt_token_lists[coeff_i] if coeff_i < len(gt_token_lists) else []
                pred_toks = pred_segs[coeff_i]       if coeff_i < len(pred_segs)     else []

                gt_ids_enc = encode(gt_toks)
                exact_match = (gt_ids_enc == pred_toks)

                gt_infix   = prefix_tokens_to_infix(gt_toks)
                pred_infix = prefix_tokens_to_infix(decode(pred_toks, skip_special=False))

                # SymPy equivalence check
                pred_strs = decode(pred_toks, skip_special=False)
                gt_expr_i = gt_coeffs[coeff_i] if coeff_i < len(gt_coeffs) else sp.Integer(0)
                s_match = sympy_equiv(pred_strs, gt_expr_i)

                if exact_match:
                    n_coeff_exact += 1
                if s_match:
                    n_coeff_sympy += 1

                status_e = "OK" if exact_match else "--"
                status_s = "OK" if s_match else "--"
                print(
                    f"       c{coeff_i} [exact={status_e} sympy={status_s}]"
                    f"  gt={gt_infix}"
                    f"  pred={pred_infix}"
                )

                coeff_results.append({
                    "coeff_idx": coeff_i,
                    "gt_infix": gt_infix,
                    "pred_infix": pred_infix,
                    "exact_match": exact_match,
                    "sympy_match": s_match,
                })

            all_exact = (n_coeff_exact == N_COEFFS)
            all_sympy = (n_coeff_sympy == N_COEFFS)
            if all_exact:
                n_fn_exact += 1
            if all_sympy:
                n_fn_sympy += 1

            print(f"       => exact: {n_coeff_exact}/{N_COEFFS}  sympy: {n_coeff_sympy}/{N_COEFFS}")

            if logger is not None:
                logger.log_eval_function_result(fn_str, coeff_results, all_exact, all_sympy)

    if n_fn_attempted:
        print(f"\n  Result: exact={n_fn_exact}/{n_fn_attempted}"
              f" ({100*n_fn_exact/n_fn_attempted:.1f}%)"
              f"  sympy={n_fn_sympy}/{n_fn_attempted}"
              f" ({100*n_fn_sympy/n_fn_attempted:.1f}%)")

    return n_fn_exact, n_fn_sympy, n_fn_attempted


def save_checkpoint(
    model:      nn.Module,
    path:       str,
    epoch:      int,
    val_metrics: Dict,
    arch_cfg:   Dict,
    model_type: str,
) -> None:
    os.makedirs(os.path.dirname(os.path.abspath(path)), exist_ok=True)
    torch.save(
        {
            "epoch":       epoch,
            "n_coeffs":    N_COEFFS,
            "val_loss":    val_metrics.get("val_loss", float("inf")),
            "model_state": model.state_dict(),
            "config":      arch_cfg,
            "model_type":  model_type,
        },
        path,
    )
    print(f"  [save] checkpoint → {path}  (epoch={epoch})")

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════

# ── Demo mode (set True to run only 2 epochs for quick testing) ───────────
DEMO_RUN = False
DEMO_EPOCHS = 2

# ── Model selection ───────────────────────────────────────────────────────
# MODEL_TYPE = "lstm"  # "transformer" or "lstm"
MODEL_TYPE = "transformer"

TRANSFORMER_CONFIG = {
    "d_model": 256,
    "nhead": 8,
    "num_encoder_layers": 3,
    "num_decoder_layers": 8,
    "dim_feedforward": 256,
    "dropout": 0.1
}

LSTM_CONFIG = {
    "d_model": 256,
    "hidden_size": 256,
    "num_encoder_layers": 2,
    "num_decoder_layers": 4,
    "dropout": 0.1
}

# ── Paths ─────────────────────────────────────────────────────────────────
DATASET_JSON    = "/kaggle/input/datasets/tensorpanda231/taylor-series-dataset-simple/taylor_dataset_100k.json"
CHECKPOINT_DIR  = "checkpoints"
CHECKPOINT_PATH = os.path.join(CHECKPOINT_DIR, f"taylor_series_pred_{MODEL_TYPE}.pt")

# ── Data split ────────────────────────────────────────────────────────────
VAL_RATIO   = 0.10
RANDOM_SEED = 1326

# ── Training ──────────────────────────────────────────────────────────────
BATCH_SIZE  = 64
NUM_EPOCHS  = 30
LR          = 3e-4
CLIP_GRAD   = 1.0
NUM_WORKERS = 0
PATIENCE    = 10  # early stopping patience (epochs without val_loss improvement)

# ── Post-training evaluation ──────────────────────────────────────────────
MAX_GEN_LEN = 512          # max decode steps for post-training greedy eval
MAX_SEQ_LEN = 512

# ── Report output ────────────────────────────────────────────────────
OUTPUT_DIR = os.path.join("reports", f"{MODEL_TYPE}_{time.strftime('%Y%m%d_%H%M%S')}")

# ── Override epochs if demo mode ──────────────────────────────────────────
if DEMO_RUN:
    NUM_EPOCHS = DEMO_EPOCHS
    print(f"  ** DEMO MODE: training for {DEMO_EPOCHS} epochs only **")


# ══════════════════════════════════════════════════════════════════════════════
# SETUP
# ══════════════════════════════════════════════════════════════════════════════

set_seed(RANDOM_SEED)
device = get_device()
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

print("=" * 68)
print(f"  coeff_pred training — unified model ({N_COEFFS} coefficients)")
print(f"  device  : {device}")
print(f"  dataset : {DATASET_JSON}")
print(f"  model   : {MODEL_TYPE}")
print(f"  seed    : {RANDOM_SEED}")
print(f"  epochs  : {NUM_EPOCHS}  (patience={PATIENCE})")
print("=" * 68)


# ══════════════════════════════════════════════════════════════════════════════
# DATA LOADING
# ══════════════════════════════════════════════════════════════════════════════

train_loader, val_loader, full_ds = build_dataloaders(
    DATASET_JSON, VAL_RATIO, RANDOM_SEED, BATCH_SIZE, NUM_WORKERS,
    max_seq_len=MAX_SEQ_LEN,
)
print(f"\n  Dataset  : {len(full_ds)} items  (skipped={full_ds.n_skipped})")
print(f"  Train    : {len(train_loader.dataset)}   Val : {len(val_loader.dataset)}\n")


# ══════════════════════════════════════════════════════════════════════════════
# MODEL INITIALIZATION
# ══════════════════════════════════════════════════════════════════════════════

arch_cfg = TRANSFORMER_CONFIG if MODEL_TYPE == "transformer" else LSTM_CONFIG
model    = build_model(MODEL_TYPE, arch_cfg).to(device)
n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"  Params   : {n_params:,}   VOCAB_SIZE={VOCAB_SIZE}\n")


# ══════════════════════════════════════════════════════════════════════════════
# REPORT LOGGER
# ══════════════════════════════════════════════════════════════════════════════

logger = ReportLogger(output_dir=OUTPUT_DIR)
logger.log_config({
    "model_type": MODEL_TYPE,
    **arch_cfg,
    "optimizer": "Adam",
    "lr": LR,
    "scheduler": "CosineAnnealingLR",
    "batch_size": BATCH_SIZE,
    "epochs": NUM_EPOCHS,
    "patience": PATIENCE,
    "gradient_clipping": CLIP_GRAD,
    "dataset_size": len(full_ds),
    "train_size": len(train_loader.dataset),
    "val_size": len(val_loader.dataset),
    "vocab_size": VOCAB_SIZE,
    "max_seq_len": MAX_SEQ_LEN,
    "n_params": n_params,
    "seed": RANDOM_SEED,
    "demo_run": DEMO_RUN,
})


# ══════════════════════════════════════════════════════════════════════════════
# OPTIMIZER / LOSS / SCHEDULER
# ══════════════════════════════════════════════════════════════════════════════

criterion = nn.CrossEntropyLoss(ignore_index=PAD_ID, reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=NUM_EPOCHS, eta_min=LR * 1e-2,
)
# Out:
# ====================================================================
#   coeff_pred training — unified model (5 coefficients)
#   device  : cuda
#   dataset : /kaggle/input/datasets/tensorpanda231/taylor-series-dataset-simple/taylor_dataset_100k.json
#   model   : transformer
#   seed    : 1326
#   epochs  : 30  (patience=10)
# ====================================================================
#
#   Dataset  : 99443 items  (skipped=557)
#   Train    : 89499   Val : 9944
#
#   Params   : 6,470,400   VOCAB_SIZE=29

# %%
# ══════════════════════════════════════════════════════════════════════════════
# TRAINING LOOP (with early stopping)
# ══════════════════════════════════════════════════════════════════════════════

best_val_loss = float("inf")
patience_counter = 0

for epoch in range(1, NUM_EPOCHS + 1):
    t0      = time.perf_counter()
    train_m = train_epoch(model, train_loader, optimizer, criterion, device, CLIP_GRAD,
                          log_every=10 if epoch == 1 else 0)

    val_m   = validate(model, val_loader, criterion, device)
    scheduler.step()

    elapsed = time.perf_counter() - t0
    is_best = val_m["val_loss"] < best_val_loss

    # Save checkpoint every epoch (for post-training evaluation).
    ckpt_path = os.path.join(CHECKPOINT_DIR, f"epoch_{epoch:03d}.pt")
    torch.save(
        {
            "epoch":       epoch,
            "model_state": model.state_dict(),
            "val_loss":    val_m["val_loss"],
            "n_coeffs":    N_COEFFS,
            "config":      arch_cfg,
            "model_type":  MODEL_TYPE,
        },
        ckpt_path,
    )

    if is_best:
        best_val_loss = val_m["val_loss"]
        patience_counter = 0
        save_checkpoint(model, CHECKPOINT_PATH, epoch, val_m, arch_cfg, MODEL_TYPE)
    else:
        patience_counter += 1

    print_epoch(epoch, NUM_EPOCHS, train_m, val_m, elapsed, is_best)

    logger.log_epoch(epoch, {
        "train_loss": train_m["train_loss"],
        "val_loss": val_m["val_loss"],
        "train_tok_acc": train_m["train_tok_acc"],
        "val_tok_acc": val_m["val_tok_acc"],
        "train_sent_acc": train_m["train_sent_acc"],
        "val_sent_acc": val_m["val_sent_acc"],
    })

    # Early stopping check
    if patience_counter >= PATIENCE:
        print(f"\n  Early stopping triggered at epoch {epoch} (no improvement for {PATIENCE} epochs)")
        break

print(f"\n  Training complete.  Best val loss: {best_val_loss:.6f}")
print(f"  Best checkpoint: {CHECKPOINT_PATH}")
# Out:
#     step   10/1399  loss=9.6718  tok_acc=0.115  sent_acc=0.000  elapsed=7.6s  ETA ~17m39s
#     step   20/1399  loss=6.5493  tok_acc=0.187  sent_acc=0.000  elapsed=14.2s  ETA ~16m15s
#     step   30/1399  loss=5.1842  tok_acc=0.234  sent_acc=0.000  elapsed=20.6s  ETA ~15m38s
#     step   40/1399  loss=4.3982  tok_acc=0.271  sent_acc=0.000  elapsed=26.8s  ETA ~15m11s
#     step   50/1399  loss=3.8935  tok_acc=0.299  sent_acc=0.000  elapsed=33.3s  ETA ~14m59s
#     step   60/1399  loss=3.5422  tok_acc=0.319  sent_acc=0.002  elapsed=39.9s  ETA ~14m49s
#     step   70/1399  loss=3.2764  tok_acc=0.336  sent_acc=0.002  elapsed=46.4s  ETA ~14m40s
#     step   80/1399  loss=3.0713  tok_acc=0.350  sent_acc=0.003  elapsed=52.8s  ETA ~14m30s
#     step   90/1399  loss=2.9075  tok_acc=0.362  sent_acc=0.007  elapsed=59.3s  ETA ~14m22s
#     step  100/1399  loss=2.7687  tok_acc=0.374  sent_acc=0.011  elapsed=65.9s  ETA ~14m15s
#     step  110/1399  loss=2.6504  tok_acc=0.385  sent_acc=0.015  elapsed=71.9s  ETA ~14m02s
#     step  120/1399  loss=2.5531  tok_acc=0.393  sent_acc=0.021  elapsed=78.5s  ETA ~13m56s
#     step  130/1399  loss=2.4664  tok_acc=0.401  sent_acc=0.027  elapsed=85.0s  ETA ~13m49s
#     step  140/1399  loss=2.3935  tok_acc=0.408  sent_acc=0.032  elapsed=91.5s  ETA ~13m42s
#     step  150/1399  loss=2.3261  tok_acc=0.416  sent_acc=0.038  elapsed=97.9s  ETA ~13m35s
#     step  160/1399  loss=2.2669  tok_acc=0.422  sent_acc=0.045  elapsed=104.4s  ETA ~13m28s
#     step  170/1399  loss=2.2129  tok_acc=0.428  sent_acc=0.053  elapsed=110.9s  ETA ~13m21s
#     step  180/1399  loss=2.1642  tok_acc=0.434  sent_acc=0.060  elapsed=117.4s  ETA ~13m15s
#     step  190/1399  loss=2.1190  tok_acc=0.439  sent_acc=0.065  elapsed=124.0s  ETA ~13m08s
#     step  200/1399  loss=2.0766  tok_acc=0.445  sent_acc=0.070  elapsed=130.4s  ETA ~13m01s
#     step  210/1399  loss=2.0369  tok_acc=0.450  sent_acc=0.075  elapsed=136.5s  ETA ~12m53s
#     step  220/1399  loss=2.0016  tok_acc=0.455  sent_acc=0.078  elapsed=143.0s  ETA ~12m46s
#     step  230/1399  loss=1.9677  tok_acc=0.460  sent_acc=0.083  elapsed=149.4s  ETA ~12m39s
#     step  240/1399  loss=1.9368  tok_acc=0.464  sent_acc=0.089  elapsed=155.9s  ETA ~12m33s
#     step  250/1399  loss=1.9082  tok_acc=0.468  sent_acc=0.094  elapsed=162.5s  ETA ~12m26s
#     step  260/1399  loss=1.8813  tok_acc=0.472  sent_acc=0.099  elapsed=169.0s  ETA ~12m20s
#     step  270/1399  loss=1.8559  tok_acc=0.476  sent_acc=0.102  elapsed=175.5s  ETA ~12m14s
#     step  280/1399  loss=1.8318  tok_acc=0.479  sent_acc=0.105  elapsed=182.1s  ETA ~12m07s
#     step  290/1399  loss=1.8071  tok_acc=0.483  sent_acc=0.109  elapsed=188.4s  ETA ~12m00s
#     step  300/1399  loss=1.7847  tok_acc=0.487  sent_acc=0.113  elapsed=194.8s  ETA ~11m53s
#     step  310/1399  loss=1.7638  tok_acc=0.490  sent_acc=0.116  elapsed=201.4s  ETA ~11m47s
#     step  320/1399  loss=1.7419  tok_acc=0.494  sent_acc=0.121  elapsed=207.9s  ETA ~11m40s
#     step  330/1399  loss=1.7226  tok_acc=0.498  sent_acc=0.124  elapsed=214.2s  ETA ~11m33s
#     step  340/1399  loss=1.7039  tok_acc=0.501  sent_acc=0.128  elapsed=220.3s  ETA ~11m26s
#     step  350/1399  loss=1.6853  tok_acc=0.505  sent_acc=0.131  elapsed=226.5s  ETA ~11m18s
#     step  360/1399  loss=1.6677  tok_acc=0.508  sent_acc=0.135  elapsed=233.0s  ETA ~11m12s
#     step  370/1399  loss=1.6517  tok_acc=0.511  sent_acc=0.138  elapsed=239.5s  ETA ~11m06s
#     step  380/1399  loss=1.6350  tok_acc=0.514  sent_acc=0.141  elapsed=245.8s  ETA ~10m59s
#     step  390/1399  loss=1.6184  tok_acc=0.518  sent_acc=0.145  elapsed=252.3s  ETA ~10m52s
#     step  400/1399  loss=1.6038  tok_acc=0.520  sent_acc=0.147  elapsed=258.7s  ETA ~10m46s
#     step  410/1399  loss=1.5896  tok_acc=0.523  sent_acc=0.149  elapsed=265.2s  ETA ~10m39s
#     step  420/1399  loss=1.5745  tok_acc=0.526  sent_acc=0.152  elapsed=271.7s  ETA ~10m33s
#     step  430/1399  loss=1.5609  tok_acc=0.529  sent_acc=0.155  elapsed=278.0s  ETA ~10m26s
#     step  440/1399  loss=1.5474  tok_acc=0.532  sent_acc=0.157  elapsed=284.4s  ETA ~10m19s
#     step  450/1399  loss=1.5342  tok_acc=0.535  sent_acc=0.159  elapsed=290.8s  ETA ~10m13s
#     step  460/1399  loss=1.5213  tok_acc=0.537  sent_acc=0.162  elapsed=297.3s  ETA ~10m06s
#     step  470/1399  loss=1.5103  tok_acc=0.540  sent_acc=0.164  elapsed=303.8s  ETA ~10m00s
#     step  480/1399  loss=1.4984  tok_acc=0.542  sent_acc=0.166  elapsed=310.3s  ETA ~9m54s
#     step  490/1399  loss=1.4865  tok_acc=0.545  sent_acc=0.170  elapsed=316.8s  ETA ~9m47s
#     step  500/1399  loss=1.4757  tok_acc=0.547  sent_acc=0.172  elapsed=323.4s  ETA ~9m41s
#     step  510/1399  loss=1.4650  tok_acc=0.549  sent_acc=0.175  elapsed=329.9s  ETA ~9m35s
#     step  520/1399  loss=1.4539  tok_acc=0.552  sent_acc=0.177  elapsed=336.3s  ETA ~9m28s
#     step  530/1399  loss=1.4432  tok_acc=0.554  sent_acc=0.180  elapsed=342.8s  ETA ~9m22s
#     step  540/1399  loss=1.4326  tok_acc=0.557  sent_acc=0.181  elapsed=349.3s  ETA ~9m15s
#     step  550/1399  loss=1.4223  tok_acc=0.559  sent_acc=0.183  elapsed=355.6s  ETA ~9m08s
#     step  560/1399  loss=1.4119  tok_acc=0.562  sent_acc=0.185  elapsed=361.8s  ETA ~9m02s
#     step  570/1399  loss=1.4022  tok_acc=0.564  sent_acc=0.187  elapsed=368.4s  ETA ~8m55s
#     step  580/1399  loss=1.3917  tok_acc=0.567  sent_acc=0.189  elapsed=374.8s  ETA ~8m49s
#     step  590/1399  loss=1.3821  tok_acc=0.569  sent_acc=0.191  elapsed=381.2s  ETA ~8m42s
#     step  600/1399  loss=1.3727  tok_acc=0.571  sent_acc=0.194  elapsed=387.7s  ETA ~8m36s
#     step  610/1399  loss=1.3634  tok_acc=0.574  sent_acc=0.196  elapsed=394.2s  ETA ~8m29s
#     step  620/1399  loss=1.3549  tok_acc=0.576  sent_acc=0.198  elapsed=400.6s  ETA ~8m23s
#     step  630/1399  loss=1.3462  tok_acc=0.578  sent_acc=0.200  elapsed=407.1s  ETA ~8m16s
#     step  640/1399  loss=1.3373  tok_acc=0.580  sent_acc=0.203  elapsed=413.6s  ETA ~8m10s
#     step  650/1399  loss=1.3280  tok_acc=0.582  sent_acc=0.205  elapsed=419.8s  ETA ~8m03s
#     step  660/1399  loss=1.3199  tok_acc=0.584  sent_acc=0.207  elapsed=426.3s  ETA ~7m57s
#     step  670/1399  loss=1.3117  tok_acc=0.586  sent_acc=0.208  elapsed=432.8s  ETA ~7m50s
#     step  680/1399  loss=1.3030  tok_acc=0.589  sent_acc=0.210  elapsed=439.0s  ETA ~7m44s
#     step  690/1399  loss=1.2941  tok_acc=0.591  sent_acc=0.212  elapsed=444.6s  ETA ~7m36s
#     step  700/1399  loss=1.2860  tok_acc=0.593  sent_acc=0.214  elapsed=450.9s  ETA ~7m30s
#     step  710/1399  loss=1.2786  tok_acc=0.595  sent_acc=0.216  elapsed=457.5s  ETA ~7m23s
#     step  720/1399  loss=1.2714  tok_acc=0.597  sent_acc=0.218  elapsed=464.0s  ETA ~7m17s
#     step  730/1399  loss=1.2636  tok_acc=0.599  sent_acc=0.220  elapsed=470.5s  ETA ~7m11s
#     step  740/1399  loss=1.2565  tok_acc=0.600  sent_acc=0.221  elapsed=476.8s  ETA ~7m04s
#     step  750/1399  loss=1.2493  tok_acc=0.602  sent_acc=0.223  elapsed=483.4s  ETA ~6m58s
#     step  760/1399  loss=1.2421  tok_acc=0.604  sent_acc=0.225  elapsed=489.9s  ETA ~6m51s
#     step  770/1399  loss=1.2352  tok_acc=0.606  sent_acc=0.227  elapsed=496.3s  ETA ~6m45s
#     step  780/1399  loss=1.2280  tok_acc=0.608  sent_acc=0.229  elapsed=502.5s  ETA ~6m38s
#     step  790/1399  loss=1.2213  tok_acc=0.610  sent_acc=0.230  elapsed=508.9s  ETA ~6m32s
#     step  800/1399  loss=1.2148  tok_acc=0.611  sent_acc=0.232  elapsed=515.3s  ETA ~6m25s
#     step  810/1399  loss=1.2083  tok_acc=0.613  sent_acc=0.233  elapsed=521.8s  ETA ~6m19s
#     step  820/1399  loss=1.2015  tok_acc=0.615  sent_acc=0.235  elapsed=528.0s  ETA ~6m12s
#     step  830/1399  loss=1.1949  tok_acc=0.617  sent_acc=0.237  elapsed=534.4s  ETA ~6m06s
#     step  840/1399  loss=1.1884  tok_acc=0.618  sent_acc=0.238  elapsed=540.8s  ETA ~5m59s
#     step  850/1399  loss=1.1822  tok_acc=0.620  sent_acc=0.239  elapsed=547.3s  ETA ~5m53s
#     step  860/1399  loss=1.1763  tok_acc=0.622  sent_acc=0.241  elapsed=553.8s  ETA ~5m47s
#     step  870/1399  loss=1.1699  tok_acc=0.623  sent_acc=0.243  elapsed=560.4s  ETA ~5m40s
#     step  880/1399  loss=1.1636  tok_acc=0.625  sent_acc=0.245  elapsed=566.9s  ETA ~5m34s
#     step  890/1399  loss=1.1576  tok_acc=0.627  sent_acc=0.246  elapsed=573.4s  ETA ~5m27s
#     step  900/1399  loss=1.1513  tok_acc=0.629  sent_acc=0.248  elapsed=579.8s  ETA ~5m21s
#     step  910/1399  loss=1.1452  tok_acc=0.630  sent_acc=0.250  elapsed=586.1s  ETA ~5m14s
#     step  920/1399  loss=1.1400  tok_acc=0.632  sent_acc=0.251  elapsed=592.5s  ETA ~5m08s
#     step  930/1399  loss=1.1342  tok_acc=0.633  sent_acc=0.253  elapsed=598.9s  ETA ~5m02s
#     step  940/1399  loss=1.1288  tok_acc=0.635  sent_acc=0.254  elapsed=605.3s  ETA ~4m55s
#     step  950/1399  loss=1.1231  tok_acc=0.636  sent_acc=0.256  elapsed=611.5s  ETA ~4m48s
#     step  960/1399  loss=1.1177  tok_acc=0.638  sent_acc=0.257  elapsed=617.9s  ETA ~4m42s
#     step  970/1399  loss=1.1126  tok_acc=0.639  sent_acc=0.259  elapsed=624.3s  ETA ~4m36s
#     step  980/1399  loss=1.1072  tok_acc=0.641  sent_acc=0.260  elapsed=630.8s  ETA ~4m29s
#     step  990/1399  loss=1.1018  tok_acc=0.642  sent_acc=0.261  elapsed=637.3s  ETA ~4m23s
#     step 1000/1399  loss=1.0966  tok_acc=0.644  sent_acc=0.262  elapsed=643.8s  ETA ~4m16s
#     step 1010/1399  loss=1.0915  tok_acc=0.645  sent_acc=0.264  elapsed=650.3s  ETA ~4m10s
#     step 1020/1399  loss=1.0860  tok_acc=0.647  sent_acc=0.265  elapsed=656.4s  ETA ~4m03s
#     step 1030/1399  loss=1.0809  tok_acc=0.648  sent_acc=0.267  elapsed=662.7s  ETA ~3m57s
#     step 1040/1399  loss=1.0757  tok_acc=0.650  sent_acc=0.268  elapsed=669.2s  ETA ~3m50s
#     step 1050/1399  loss=1.0711  tok_acc=0.651  sent_acc=0.269  elapsed=675.6s  ETA ~3m44s
#     step 1060/1399  loss=1.0660  tok_acc=0.653  sent_acc=0.271  elapsed=681.9s  ETA ~3m38s
#     step 1070/1399  loss=1.0612  tok_acc=0.654  sent_acc=0.272  elapsed=688.1s  ETA ~3m31s
#     step 1080/1399  loss=1.0564  tok_acc=0.655  sent_acc=0.273  elapsed=694.1s  ETA ~3m25s
#     step 1090/1399  loss=1.0519  tok_acc=0.657  sent_acc=0.274  elapsed=700.7s  ETA ~3m18s
#     step 1100/1399  loss=1.0471  tok_acc=0.658  sent_acc=0.276  elapsed=707.2s  ETA ~3m12s
#     step 1110/1399  loss=1.0423  tok_acc=0.659  sent_acc=0.277  elapsed=713.7s  ETA ~3m05s
#     step 1120/1399  loss=1.0377  tok_acc=0.661  sent_acc=0.278  elapsed=719.9s  ETA ~2m59s
#     step 1130/1399  loss=1.0330  tok_acc=0.662  sent_acc=0.280  elapsed=726.3s  ETA ~2m52s
#     step 1140/1399  loss=1.0283  tok_acc=0.663  sent_acc=0.281  elapsed=732.7s  ETA ~2m46s
#     step 1150/1399  loss=1.0239  tok_acc=0.665  sent_acc=0.282  elapsed=739.3s  ETA ~2m40s
#     step 1160/1399  loss=1.0196  tok_acc=0.666  sent_acc=0.283  elapsed=745.6s  ETA ~2m33s
#     step 1170/1399  loss=1.0153  tok_acc=0.667  sent_acc=0.284  elapsed=752.1s  ETA ~2m27s
#     step 1180/1399  loss=1.0111  tok_acc=0.668  sent_acc=0.286  elapsed=758.6s  ETA ~2m20s
#     step 1190/1399  loss=1.0068  tok_acc=0.670  sent_acc=0.287  elapsed=764.8s  ETA ~2m14s
#     step 1200/1399  loss=1.0027  tok_acc=0.671  sent_acc=0.288  elapsed=771.1s  ETA ~2m07s
#     step 1210/1399  loss=0.9986  tok_acc=0.672  sent_acc=0.289  elapsed=777.2s  ETA ~2m01s
#     step 1220/1399  loss=0.9946  tok_acc=0.673  sent_acc=0.290  elapsed=783.4s  ETA ~1m54s
#     step 1230/1399  loss=0.9904  tok_acc=0.674  sent_acc=0.292  elapsed=789.9s  ETA ~1m48s
#     step 1240/1399  loss=0.9865  tok_acc=0.676  sent_acc=0.293  elapsed=796.5s  ETA ~1m42s
#     step 1250/1399  loss=0.9825  tok_acc=0.677  sent_acc=0.294  elapsed=802.9s  ETA ~1m35s
#     step 1260/1399  loss=0.9785  tok_acc=0.678  sent_acc=0.295  elapsed=809.4s  ETA ~1m29s
#     step 1270/1399  loss=0.9746  tok_acc=0.679  sent_acc=0.296  elapsed=815.7s  ETA ~1m22s
#     step 1280/1399  loss=0.9707  tok_acc=0.680  sent_acc=0.297  elapsed=822.0s  ETA ~1m16s
#     step 1290/1399  loss=0.9669  tok_acc=0.681  sent_acc=0.298  elapsed=828.3s  ETA ~1m09s
#     step 1300/1399  loss=0.9629  tok_acc=0.682  sent_acc=0.300  elapsed=834.6s  ETA ~1m03s
#     step 1310/1399  loss=0.9592  tok_acc=0.684  sent_acc=0.301  elapsed=841.0s  ETA ~57s
#     step 1320/1399  loss=0.9558  tok_acc=0.685  sent_acc=0.302  elapsed=847.5s  ETA ~50s
#     step 1330/1399  loss=0.9522  tok_acc=0.686  sent_acc=0.303  elapsed=854.1s  ETA ~44s
#     step 1340/1399  loss=0.9486  tok_acc=0.687  sent_acc=0.304  elapsed=860.6s  ETA ~37s
#     step 1350/1399  loss=0.9450  tok_acc=0.688  sent_acc=0.305  elapsed=867.1s  ETA ~31s
#     step 1360/1399  loss=0.9413  tok_acc=0.689  sent_acc=0.306  elapsed=873.7s  ETA ~25s
#     step 1370/1399  loss=0.9379  tok_acc=0.690  sent_acc=0.307  elapsed=880.2s  ETA ~18s
#     step 1380/1399  loss=0.9344  tok_acc=0.691  sent_acc=0.308  elapsed=886.7s  ETA ~12s
#     step 1390/1399  loss=0.9311  tok_acc=0.692  sent_acc=0.309  elapsed=893.1s  ETA ~5s
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=1)
#   epoch   1/30  trn_loss=0.9278  val_loss=0.3509  val_tok=0.871  val_sent=0.562  928.1s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=2)
#   epoch   2/30  trn_loss=0.3473  val_loss=0.2277  val_tok=0.916  val_sent=0.660  931.4s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=3)
#   epoch   3/30  trn_loss=0.2474  val_loss=0.1678  val_tok=0.938  val_sent=0.715  928.1s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=4)
#   epoch   4/30  trn_loss=0.2013  val_loss=0.1376  val_tok=0.949  val_sent=0.730  929.1s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=5)
#   epoch   5/30  trn_loss=0.1724  val_loss=0.1238  val_tok=0.955  val_sent=0.749  930.1s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=6)
#   epoch   6/30  trn_loss=0.1513  val_loss=0.1055  val_tok=0.961  val_sent=0.772  930.1s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=7)
#   epoch   7/30  trn_loss=0.1363  val_loss=0.0952  val_tok=0.965  val_sent=0.784  930.3s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=8)
#   epoch   8/30  trn_loss=0.1235  val_loss=0.0874  val_tok=0.968  val_sent=0.789  932.1s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=9)
#   epoch   9/30  trn_loss=0.1140  val_loss=0.0829  val_tok=0.970  val_sent=0.799  931.8s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=10)
#   epoch  10/30  trn_loss=0.1053  val_loss=0.0772  val_tok=0.972  val_sent=0.803  931.2s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=11)
#   epoch  11/30  trn_loss=0.0981  val_loss=0.0745  val_tok=0.973  val_sent=0.809  932.7s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=12)
#   epoch  12/30  trn_loss=0.0920  val_loss=0.0675  val_tok=0.976  val_sent=0.817  935.9s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=13)
#   epoch  13/30  trn_loss=0.0861  val_loss=0.0657  val_tok=0.976  val_sent=0.825  934.3s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=14)
#   epoch  14/30  trn_loss=0.0811  val_loss=0.0610  val_tok=0.978  val_sent=0.833  932.6s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=15)
#   epoch  15/30  trn_loss=0.0765  val_loss=0.0588  val_tok=0.979  val_sent=0.836  933.8s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=16)
#   epoch  16/30  trn_loss=0.0726  val_loss=0.0560  val_tok=0.980  val_sent=0.844  933.0s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=17)
#   epoch  17/30  trn_loss=0.0688  val_loss=0.0534  val_tok=0.981  val_sent=0.847  931.5s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=18)
#   epoch  18/30  trn_loss=0.0653  val_loss=0.0511  val_tok=0.982  val_sent=0.850  930.6s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=19)
#   epoch  19/30  trn_loss=0.0621  val_loss=0.0491  val_tok=0.983  val_sent=0.863  929.0s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=20)
#   epoch  20/30  trn_loss=0.0597  val_loss=0.0482  val_tok=0.983  val_sent=0.864  931.3s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=21)
#   epoch  21/30  trn_loss=0.0570  val_loss=0.0472  val_tok=0.984  val_sent=0.867  931.7s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=22)
#   epoch  22/30  trn_loss=0.0547  val_loss=0.0459  val_tok=0.984  val_sent=0.872  932.6s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=23)
#   epoch  23/30  trn_loss=0.0527  val_loss=0.0457  val_tok=0.984  val_sent=0.857  932.1s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=24)
#   epoch  24/30  trn_loss=0.0509  val_loss=0.0442  val_tok=0.985  val_sent=0.877  932.3s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=25)
#   epoch  25/30  trn_loss=0.0497  val_loss=0.0435  val_tok=0.985  val_sent=0.880  931.0s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=26)
#   epoch  26/30  trn_loss=0.0481  val_loss=0.0430  val_tok=0.985  val_sent=0.881  931.7s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=27)
#   epoch  27/30  trn_loss=0.0470  val_loss=0.0426  val_tok=0.985  val_sent=0.882  929.7s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=28)
#   epoch  28/30  trn_loss=0.0463  val_loss=0.0424  val_tok=0.985  val_sent=0.881  931.7s  ETA 0s  *best*
#   [save] checkpoint → checkpoints/taylor_series_pred_transformer.pt  (epoch=29)
#   epoch  29/30  trn_loss=0.0461  val_loss=0.0421  val_tok=0.986  val_sent=0.882  931.5s  ETA 0s  *best*
#   epoch  30/30  trn_loss=0.0457  val_loss=0.0422  val_tok=0.986  val_sent=0.883  931.3s
#
#   Training complete.  Best val loss: 0.042106
#   Best checkpoint: checkpoints/taylor_series_pred_transformer.pt

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LOAD BEST MODEL
# ══════════════════════════════════════════════════════════════════════════════

print("\n  Loading best model for evaluation ...")
ckpt = torch.load(CHECKPOINT_PATH, map_location=device, weights_only=True)
model.load_state_dict(ckpt["model_state"])
model.eval()


# # ══════════════════════════════════════════════════════════════════════════════
# # SAMPLE PREDICTIONS
# # ══════════════════════════════════════════════════════════════════════════════

# print(f"\n  Example predictions (unified, greedy):")
# shown = 0
# with torch.no_grad():
#     for src, tgt, _, _ in val_loader:
#         src   = src.to(device)
#         preds = model.generate_batch(src, max_len=MAX_GEN_LEN)
#         for i in range(len(preds)):
#             if shown >= 4:
#                 break
#             src_tok  = decode(src[i].tolist())
#             tgt_tok  = decode(tgt[i].tolist(), skip_special=False)
#             pred_tok = decode([t for t in preds[i] if t != EOS_ID], skip_special=False)
#             print(f"  ── example {shown + 1} ──")
#             print(f"     src  : {src_tok}")
#             print(f"     tgt  : {tgt_tok}")
#             print(f"     pred : {pred_tok}")
#             print(f"     match: {'✓' if tgt_tok == pred_tok else '✗'}")
#             shown += 1
#         if shown >= 4:
#             break
# Out:
#   Loading best model for evaluation ...
# CoeffPredTransformer(
#   (embedding): Embedding(29, 256, padding_idx=0)
#   (pos_encoding): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (linear1): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=256, out_features=256, bias=True)
#         (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (decoder): TransformerDecoder(
#     (layers): ModuleList(
#       (0-7): 8 x TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (linear1): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=256, out_features=256, bias=True)
#         (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (fc_out): Linear(in_features=256, out_features=29, bias=False)
# )

# %%
# ══════════════════════════════════════════════════════════════════════════════
# FULL VALIDATION SET EVALUATION (autoregressive)
# ══════════════════════════════════════════════════════════════════════════════

print("\n" + "=" * 68)
print("  Full validation set evaluation (autoregressive decoding)")
print("=" * 68)

all_pred_ids = []
all_tgt_ids  = []
pred_lengths = []
gt_lengths   = []
n_fn_level_correct = 0
n_fn_level_total   = 0

with torch.no_grad():
    for batch_idx, (src, tgt, _, _) in enumerate(val_loader):
        src = src.to(device)
        preds = model.generate_batch(src, max_len=MAX_GEN_LEN)

        for i in range(len(preds)):
            pred_seq = preds[i]
            tgt_seq  = tgt[i].tolist()

            # strip SOS from target for comparison
            tgt_stripped = [t for t in tgt_seq[1:] if t != PAD_ID]

            all_pred_ids.append(pred_seq)
            all_tgt_ids.append(tgt_stripped)

            # sequence lengths (up to EOS)
            pred_len = len(pred_seq)
            for pi, tid in enumerate(pred_seq):
                if tid == EOS_ID:
                    pred_len = pi
                    break
            gt_len = len(tgt_stripped)
            for gi, tid in enumerate(tgt_stripped):
                if tid == EOS_ID:
                    gt_len = gi
                    break
            pred_lengths.append(pred_len)
            gt_lengths.append(gt_len)

            # function-level accuracy: all segments must match exactly
            pred_segs = split_segments(pred_seq, BREAK_ID, EOS_ID, PAD_ID)
            tgt_segs  = split_segments(tgt_stripped, BREAK_ID, EOS_ID, PAD_ID)
            n_fn_level_total += 1
            if len(pred_segs) == len(tgt_segs) == N_COEFFS:
                if all(pred_segs[j] == tgt_segs[j] for j in range(N_COEFFS)):
                    n_fn_level_correct += 1

        if (batch_idx + 1) % 10 == 0:
            print(f"    batch {batch_idx + 1}/{len(val_loader)} ...")
# Out:
# ====================================================================
#   Full validation set evaluation (autoregressive decoding)
# ====================================================================
#     batch 10/156 ...
#     batch 20/156 ...
#     batch 30/156 ...
#     batch 40/156 ...
#     batch 50/156 ...
#     batch 60/156 ...
#     batch 70/156 ...
#     batch 80/156 ...
#     batch 90/156 ...
#     batch 100/156 ...
#     batch 110/156 ...
#     batch 120/156 ...
#     batch 130/156 ...
#     batch 140/156 ...
#     batch 150/156 ...

# %%
# ══════════════════════════════════════════════════════════════════════════════
# COMPUTE METRICS
# ══════════════════════════════════════════════════════════════════════════════

# per-segment (per-coefficient) metrics
seg_metrics = per_segment_metrics(all_pred_ids, all_tgt_ids, PAD_ID, BREAK_ID, N_COEFFS)

# aggregate metrics across all coefficients
from metrics import token_accuracy, sentence_accuracy

# build padded tensors for aggregate token/sentence accuracy
max_pred = max((len(p) for p in all_pred_ids), default=1)
max_tgt  = max((len(t) for t in all_tgt_ids),  default=1)
L = max(max_pred, max_tgt)
N = len(all_pred_ids)
pred_tensor = torch.full((N, L), PAD_ID, dtype=torch.long)
tgt_tensor  = torch.full((N, L), PAD_ID, dtype=torch.long)
for i, (p, t) in enumerate(zip(all_pred_ids, all_tgt_ids)):
    pred_tensor[i, :len(p)] = torch.tensor(p, dtype=torch.long)
    tgt_tensor[i,  :len(t)] = torch.tensor(t, dtype=torch.long)

tok_acc  = token_accuracy(pred_tensor, tgt_tensor, PAD_ID)
sent_acc = sentence_accuracy(pred_tensor, tgt_tensor, PAD_ID)
fn_acc   = n_fn_level_correct / n_fn_level_total if n_fn_level_total else 0.0

# expression validity from per-segment metrics (average across coefficients)
expr_valid = sum(d["correct_expression"] for d in seg_metrics) / len(seg_metrics) if seg_metrics else 0.0

print(f"\n  Validation results (autoregressive):")
print(f"    Token accuracy     : {tok_acc:.4f}")
print(f"    Sequence accuracy  : {sent_acc:.4f}")
print(f"    Expression validity: {expr_valid:.4f}")
print(f"    Function-level acc : {fn_acc:.4f}  ({n_fn_level_correct}/{n_fn_level_total})")
print(f"\n  Per-coefficient breakdown:")
for i, d in enumerate(seg_metrics):
    print(f"    c{i}: tok_acc={d['token_acc']:.4f}  sent_acc={d['sentence_acc']:.4f}  valid_expr={d['correct_expression']:.4f}")

logger.log_val_eval({
    "token_accuracy": tok_acc,
    "sequence_accuracy": sent_acc,
    "expression_validity": expr_valid,
    "function_level_accuracy": fn_acc,
})
logger.log_per_coefficient_accuracy(seg_metrics)
logger.log_sequence_lengths(pred_lengths, gt_lengths)


# ══════════════════════════════════════════════════════════════════════════════
# TABLES & FIGURES
# ══════════════════════════════════════════════════════════════════════════════

import csv
import numpy as np
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

# ── Table 1: Model architecture summary ───────────────────────────────────

print("\n" + "=" * 68)
print("  Table 1: Model Architecture Summary")
print("=" * 68)
print(f"    Model type        : {MODEL_TYPE}")
print(f"    Parameters        : {n_params:,}")
if MODEL_TYPE == "transformer":
    print(f"    d_model           : {arch_cfg['d_model']}")
    print(f"    nhead             : {arch_cfg['nhead']}")
    print(f"    Encoder layers    : {arch_cfg['num_encoder_layers']}")
    print(f"    Decoder layers    : {arch_cfg['num_decoder_layers']}")
    print(f"    dim_feedforward   : {arch_cfg['dim_feedforward']}")
    print(f"    Dropout           : {arch_cfg['dropout']}")
else:
    print(f"    d_model           : {arch_cfg['d_model']}")
    print(f"    hidden_size       : {arch_cfg['hidden_size']}")
    print(f"    Encoder layers    : {arch_cfg['num_encoder_layers']}")
    print(f"    Decoder layers    : {arch_cfg['num_decoder_layers']}")
    print(f"    Dropout           : {arch_cfg['dropout']}")

# Save architecture table CSV
arch_table_path = os.path.join(OUTPUT_DIR, "architecture_summary.csv")
with open(arch_table_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["property", "value"])
    writer.writerow(["model_type", MODEL_TYPE])
    writer.writerow(["n_params", n_params])
    for k, v in arch_cfg.items():
        writer.writerow([k, v])

# ── Table 2: Overall performance summary ──────────────────────────────────

print("\n" + "=" * 68)
print("  Table 2: Overall Performance Summary")
print("=" * 68)

# Get final epoch metrics
final_epoch = logger.epoch_logs[-1] if logger.epoch_logs else {}
print(f"    Final train loss   : {final_epoch.get('train_loss', 'N/A'):.6f}")
print(f"    Final val loss     : {final_epoch.get('val_loss', 'N/A'):.6f}")
print(f"    Best val loss      : {best_val_loss:.6f}")
print(f"    Val token accuracy : {tok_acc:.4f}")
print(f"    Val sent accuracy  : {sent_acc:.4f}")
print(f"    Val func-level acc : {fn_acc:.4f}")

# Save performance summary CSV
perf_table_path = os.path.join(OUTPUT_DIR, "performance_summary.csv")
with open(perf_table_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["metric", "value"])
    writer.writerow(["model_type", MODEL_TYPE])
    writer.writerow(["seed", RANDOM_SEED])
    writer.writerow(["final_train_loss", f"{final_epoch.get('train_loss', 0):.6f}"])
    writer.writerow(["final_val_loss", f"{final_epoch.get('val_loss', 0):.6f}"])
    writer.writerow(["best_val_loss", f"{best_val_loss:.6f}"])
    writer.writerow(["val_token_accuracy", f"{tok_acc:.4f}"])
    writer.writerow(["val_sequence_accuracy", f"{sent_acc:.4f}"])
    writer.writerow(["val_expression_validity", f"{expr_valid:.4f}"])
    writer.writerow(["val_function_level_accuracy", f"{fn_acc:.4f}"])
    writer.writerow(["total_epochs_trained", len(logger.epoch_logs)])
    writer.writerow(["n_params", n_params])

# ── Table 3: Per-coefficient accuracy table ───────────────────────────────

print("\n" + "=" * 68)
print("  Table 3: Per-Coefficient Accuracy")
print("=" * 68)
print(f"    {'Coeff':<8} {'Token Acc':<12} {'Sent Acc':<12} {'Valid Expr':<12}")
print(f"    {'-'*44}")
for i, d in enumerate(seg_metrics):
    print(f"    c{i:<7} {d['token_acc']:<12.4f} {d['sentence_acc']:<12.4f} {d['correct_expression']:<12.4f}")

# Save per-coefficient CSV
coeff_table_path = os.path.join(OUTPUT_DIR, "per_coefficient_accuracy.csv")
with open(coeff_table_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["coefficient", "token_acc", "sentence_acc", "correct_expression"])
    for i, d in enumerate(seg_metrics):
        writer.writerow([f"c{i}", f"{d['token_acc']:.4f}", f"{d['sentence_acc']:.4f}", f"{d['correct_expression']:.4f}"])

# ── Table 4: Full run CSV (epoch_logs already saved by logger) ────────────

# Already saved via logger._save_epoch_csv(), but save an explicit copy
full_run_csv_path = os.path.join(OUTPUT_DIR, "full_run_metrics.csv")
with open(full_run_csv_path, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=[
        "epoch", "train_loss", "val_loss",
        "train_tok_acc", "val_tok_acc",
        "train_sent_acc", "val_sent_acc",
    ], extrasaction="ignore")
    writer.writeheader()
    writer.writerows(logger.epoch_logs)

print(f"\n  Full run metrics saved to {full_run_csv_path}")
# Out:
#   Validation results (autoregressive):
#     Token accuracy     : 0.7833
#     Sequence accuracy  : 0.8825
#     Expression validity: 0.9838
#     Function-level acc : 0.8825  (8776/9944)
#
#   Per-coefficient breakdown:
#     c0: tok_acc=0.9808  sent_acc=0.9822  valid_expr=0.9988
#     c1: tok_acc=0.9262  sent_acc=0.9449  valid_expr=0.9967
#     c2: tok_acc=0.8396  sent_acc=0.9189  valid_expr=0.9897
#     c3: tok_acc=0.7421  sent_acc=0.9042  valid_expr=0.9788
#     c4: tok_acc=0.7935  sent_acc=0.9050  valid_expr=0.9550
#
# ====================================================================
#   Table 1: Model Architecture Summary
# ====================================================================
#     Model type        : transformer
#     Parameters        : 6,470,400
#     d_model           : 256
#     nhead             : 8
#     Encoder layers    : 3
#     Decoder layers    : 8
#     dim_feedforward   : 256
#     Dropout           : 0.1
#
# ====================================================================
#   Table 2: Overall Performance Summary
# ====================================================================
#     Final train loss   : 0.045651
#     Final val loss     : 0.042164
#     Best val loss      : 0.042106
#     Val token accuracy : 0.7833
#     Val sent accuracy  : 0.8825
#     Val func-level acc : 0.8825
#
# ====================================================================
#   Table 3: Per-Coefficient Accuracy
# ====================================================================
#     Coeff    Token Acc    Sent Acc     Valid Expr
#     --------------------------------------------
#     c0       0.9808       0.9822       0.9988
#     c1       0.9262       0.9449       0.9967
#     c2       0.8396       0.9189       0.9897
#     c3       0.7421       0.9042       0.9788
#     c4       0.7935       0.9050       0.9550
#
#   Full run metrics saved to reports/transformer_20260312_135140/full_run_metrics.csv

# %%
# ── Figure 1: Train/Val loss curves ──────────────────────────────────────
# %matplotlib inline
epochs_list = [e["epoch"] for e in logger.epoch_logs]
train_losses = [e["train_loss"] for e in logger.epoch_logs]
val_losses = [e["val_loss"] for e in logger.epoch_logs]

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(epochs_list, train_losses, label="Train Loss", color="tab:blue", linewidth=2)
ax.plot(epochs_list, val_losses, label="Val Loss", color="tab:orange", linewidth=2)
ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Loss", fontsize=12)
ax.set_title(f"Train/Val Loss — {MODEL_TYPE.upper()} (10k samples, seed={RANDOM_SEED})", fontsize=14)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
fig.savefig(os.path.join(OUTPUT_DIR, "fig1_loss_curves.png"), dpi=150, bbox_inches="tight")
# plt.close(fig)
print(f"  Figure 1 saved: fig1_loss_curves.png")
plt.show()
# Out:
#   Figure 1 saved: fig1_loss_curves.png

# %%
# %matplotlib inline

# ── Figure 2: Sentence accuracy over epochs ──────────────────────────────

train_sent_accs = [e["train_sent_acc"] for e in logger.epoch_logs]
val_sent_accs = [e["val_sent_acc"] for e in logger.epoch_logs]

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(epochs_list, train_sent_accs, label="Train Sent Acc", color="tab:blue", linewidth=2)
ax.plot(epochs_list, val_sent_accs, label="Val Sent Acc", color="tab:orange", linewidth=2)
ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Sentence Accuracy", fontsize=12)
ax.set_title(f"Sentence Accuracy — {MODEL_TYPE.upper()} (10k samples, seed={RANDOM_SEED})", fontsize=14)
ax.set_ylim(0, 1.05)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
fig.savefig(os.path.join(OUTPUT_DIR, "fig2_sentence_accuracy.png"), dpi=150, bbox_inches="tight")
# plt.close(fig)
print(f"  Figure 2 saved: fig2_sentence_accuracy.png")
plt.show()
# Out:
#   Figure 2 saved: fig2_sentence_accuracy.png

# %%
# ── Figure 3: Per-coefficient accuracy bar chart ─────────────────────────
# %matplotlib inline

coeff_labels = [f"c{i}" for i in range(N_COEFFS)]
tok_accs = [d["token_acc"] for d in seg_metrics]
sent_accs_coeff = [d["sentence_acc"] for d in seg_metrics]
expr_valids = [d["correct_expression"] for d in seg_metrics]

x = np.arange(N_COEFFS)
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width, tok_accs, width, label="Token Acc", color="tab:blue")
bars2 = ax.bar(x, sent_accs_coeff, width, label="Sentence Acc", color="tab:green")
bars3 = ax.bar(x + width, expr_valids, width, label="Valid Expression", color="tab:red")

ax.set_xlabel("Coefficient", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.set_title(f"Per-Coefficient Accuracy — {MODEL_TYPE.upper()} (10k samples, seed={RANDOM_SEED})", fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(coeff_labels)
ax.set_ylim(0, 1.05)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3, axis="y")

# Add value labels on bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        height = bar.get_height()
        if height > 0.02:
            ax.annotate(f'{height:.2f}',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3), textcoords="offset points",
                        ha='center', va='bottom', fontsize=8)

fig.savefig(os.path.join(OUTPUT_DIR, "fig3_per_coefficient_accuracy.png"), dpi=150, bbox_inches="tight")
# plt.close(fig)
print(f"  Figure 3 saved: fig3_per_coefficient_accuracy.png")
plt.show()
# Out:
#   Figure 3 saved: fig3_per_coefficient_accuracy.png

# %%
# ── Figure 4: Token accuracy over epochs ─────────────────────────────────

train_tok_accs = [e["train_tok_acc"] for e in logger.epoch_logs]
val_tok_accs = [e["val_tok_acc"] for e in logger.epoch_logs]

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(epochs_list, train_tok_accs, label="Train Token Acc", color="tab:blue", linewidth=2)
ax.plot(epochs_list, val_tok_accs, label="Val Token Acc", color="tab:orange", linewidth=2)
ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Token Accuracy", fontsize=12)
ax.set_title(f"Token Accuracy — {MODEL_TYPE.upper()} (10k samples, seed={RANDOM_SEED})", fontsize=14)
ax.set_ylim(0, 1.05)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
fig.savefig(os.path.join(OUTPUT_DIR, "fig4_token_accuracy.png"), dpi=150, bbox_inches="tight")
# plt.close(fig)
print(f"  Figure 4 saved: fig4_token_accuracy.png")
plt.show()
# Out:
#   Figure 4 saved: fig4_token_accuracy.png

# %%
# ── Figure 5: Sequence length histogram ──────────────────────────────────

fig, ax = plt.subplots(figsize=(10, 6))
ax.hist(gt_lengths, bins=30, alpha=0.6, label="Ground Truth", color="tab:blue")
ax.hist(pred_lengths, bins=30, alpha=0.6, label="Predicted", color="tab:orange")
ax.set_xlabel("Sequence Length", fontsize=12)
ax.set_ylabel("Count", fontsize=12)
ax.set_title(f"Predicted vs Ground Truth Sequence Lengths — {MODEL_TYPE.upper()}", fontsize=14)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
fig.savefig(os.path.join(OUTPUT_DIR, "fig5_sequence_lengths.png"), dpi=150, bbox_inches="tight")
# plt.close(fig)
print(f"  Figure 5 saved: fig5_sequence_lengths.png")

plt.show()
# Out:
#   Figure 5 saved: fig5_sequence_lengths.png

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CUSTOM TEST FUNCTIONS EVALUATION (final, with SymPy)
# ══════════════════════════════════════════════════════════════════════════════

print("\n" + "=" * 68)
print("  Final evaluation on CUSTOM_TEST_FUNCTIONS (exact + SymPy)")
print("=" * 68)
run_custom_test_functions(model, device, logger=logger, max_gen_len=MAX_GEN_LEN)
print("=" * 68)


# ══════════════════════════════════════════════════════════════════════════════
# GENERATE REPORT
# ══════════════════════════════════════════════════════════════════════════════

logger.generate_report()
print(f"\n  Report saved to {OUTPUT_DIR}/")
print(f"  All tables and figures generated successfully.")
# Out:
# ====================================================================
#   Final evaluation on CUSTOM_TEST_FUNCTIONS (exact + SymPy)
# ====================================================================
#
#   [ 1] f(x) = (x**2 + 1)*sin(x)
#        c0 [exact=OK sympy=OK]  gt=a**2*sin(a) + sin(a)  pred=a**2*sin(a) + sin(a)
#        c1 [exact=OK sympy=OK]  gt=a**2*cos(a) + 2*a*sin(a) + cos(a)  pred=a**2*cos(a) + 2*a*sin(a) + cos(a)
#        c2 [exact=-- sympy=--]  gt=-a**2*sin(a) + 4*a*cos(a) + sin(a)  pred=-a**2*sin(a) - sin(a) + 2*cos(a)
#        c3 [exact=-- sympy=--]  gt=-a**2*cos(a) - 6*a*sin(a) + 5*cos(a)  pred=-a**2*cos(a) - 6*a*sin(a) - cos(a)
#        c4 [exact=-- sympy=--]  gt=a**2*sin(a) - 8*a*cos(a) - 11*sin(a)  pred=a**2*sin(a) - 8*a*cos(a) - 12*sin(a)
#        => exact: 2/5  sympy: 2/5
#
#   [ 2] f(x) = x**3*cos(2*x)
#        c0 [exact=OK sympy=OK]  gt=a**3*cos(2*a)  pred=a**3*cos(2*a)
#        c1 [exact=OK sympy=OK]  gt=-2*a**3*sin(2*a) + 3*a**2*cos(2*a)  pred=-2*a**3*sin(2*a) + 3*a**2*cos(2*a)
#        c2 [exact=OK sympy=OK]  gt=-4*a**3*cos(2*a) - 12*a**2*sin(2*a) + 6*a*cos(2*a)  pred=-4*a**3*cos(2*a) - 12*a**2*sin(2*a) + 6*a*cos(2*a)
#        c3 [exact=-- sympy=--]  gt=8*a**3*sin(2*a) - 36*a**2*cos(2*a) - 36*a*sin(2*a) + 6*cos(2*a)  pred=8*a**3*sin(2*a) - 24*a**2*cos(2*a) - 48*a*sin(2*a) + 6*cos(2*a)
#        c4 [exact=-- sympy=--]  gt=16*a**3*cos(2*a) + 96*a**2*sin(2*a) - 144*a*cos(2*a) - 48*sin(2*a)  pred=16*a**3*cos(2*a) - 192*a**2*cos(2*a) + 384*a*cos(2*a) - 48*sin(2*a)
#        => exact: 3/5  sympy: 3/5
#
#   [ 3] f(x) = exp(x)*(1 + x)
#        c0 [exact=OK sympy=OK]  gt=a*exp(a) + exp(a)  pred=a*exp(a) + exp(a)
#        c1 [exact=OK sympy=OK]  gt=a*exp(a) + 2*exp(a)  pred=a*exp(a) + 2*exp(a)
#        c2 [exact=OK sympy=OK]  gt=a*exp(a) + 3*exp(a)  pred=a*exp(a) + 3*exp(a)
#        c3 [exact=OK sympy=OK]  gt=a*exp(a) + 4*exp(a)  pred=a*exp(a) + 4*exp(a)
#        c4 [exact=OK sympy=OK]  gt=a*exp(a) + 5*exp(a)  pred=a*exp(a) + 5*exp(a)
#        => exact: 5/5  sympy: 5/5
#
#   [ 4] f(x) = x*exp(2*x)
#        c0 [exact=OK sympy=OK]  gt=a*exp(2*a)  pred=a*exp(2*a)
#        c1 [exact=OK sympy=OK]  gt=2*a*exp(2*a) + exp(2*a)  pred=2*a*exp(2*a) + exp(2*a)
#        c2 [exact=OK sympy=OK]  gt=4*a*exp(2*a) + 4*exp(2*a)  pred=4*a*exp(2*a) + 4*exp(2*a)
#        c3 [exact=OK sympy=OK]  gt=8*a*exp(2*a) + 12*exp(2*a)  pred=8*a*exp(2*a) + 12*exp(2*a)
#        c4 [exact=OK sympy=OK]  gt=16*a*exp(2*a) + 32*exp(2*a)  pred=16*a*exp(2*a) + 32*exp(2*a)
#        => exact: 5/5  sympy: 5/5
#
#   [ 5] f(x) = (1 + x**2)*exp(-x)
#        c0 [exact=OK sympy=OK]  gt=(a**2 + 1)*exp(-a)  pred=(a**2 + 1)*exp(-a)
#        c1 [exact=-- sympy=--]  gt=(-a**2 + 2*a - 1)*exp(-a)  pred=(-a**2 + 2*a + 1)*exp(-a)
#        c2 [exact=-- sympy=--]  gt=(a**2 - 4*a + 3)*exp(-a)  pred=(a**2 - 4*a + 1)*exp(-a)
#        c3 [exact=-- sympy=--]  gt=(-a**2 + 6*a - 7)*exp(-a)  pred=(-a**2 + 6*a - 5)*exp(-a)
#        c4 [exact=-- sympy=--]  gt=(a**2 - 8*a + 13)*exp(-a)  pred=(a**2 - 8*a + 11)*exp(-a)
#        => exact: 1/5  sympy: 1/5
#
#   [ 6] f(x) = exp(x)*sin(x)
#        c0 [exact=OK sympy=OK]  gt=exp(a)*sin(a)  pred=exp(a)*sin(a)
#        c1 [exact=OK sympy=OK]  gt=exp(a)*sin(a) + exp(a)*cos(a)  pred=exp(a)*sin(a) + exp(a)*cos(a)
#        c2 [exact=OK sympy=OK]  gt=2*exp(a)*cos(a)  pred=2*exp(a)*cos(a)
#        c3 [exact=OK sympy=OK]  gt=-2*exp(a)*sin(a) + 2*exp(a)*cos(a)  pred=-2*exp(a)*sin(a) + 2*exp(a)*cos(a)
#        c4 [exact=OK sympy=OK]  gt=-4*exp(a)*sin(a)  pred=-4*exp(a)*sin(a)
#        => exact: 5/5  sympy: 5/5
#
#   [ 7] f(x) = log(1 + x)
#        c0 [exact=OK sympy=OK]  gt=log(a + 1)  pred=log(a + 1)
#        c1 [exact=OK sympy=OK]  gt=1/(a + 1)  pred=1/(a + 1)
#        c2 [exact=OK sympy=OK]  gt=-1/(a**2 + 2*a + 1)  pred=-1/(a**2 + 2*a + 1)
#        c3 [exact=OK sympy=OK]  gt=2/(a**3 + 3*a**2 + 3*a + 1)  pred=2/(a**3 + 3*a**2 + 3*a + 1)
#        c4 [exact=OK sympy=OK]  gt=-6/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)  pred=-6/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)
#        => exact: 5/5  sympy: 5/5
#
#   [ 8] f(x) = log(1 + x**2)
#        c0 [exact=OK sympy=OK]  gt=log(a**2 + 1)  pred=log(a**2 + 1)
#        c1 [exact=OK sympy=OK]  gt=2*a/(a**2 + 1)  pred=2*a/(a**2 + 1)
#        c2 [exact=OK sympy=OK]  gt=(2 - 2*a**2)/(a**4 + 2*a**2 + 1)  pred=(2 - 2*a**2)/(a**4 + 2*a**2 + 1)
#        c3 [exact=OK sympy=OK]  gt=(4*a**3 - 12*a)/(a**6 + 3*a**4 + 3*a**2 + 1)  pred=(4*a**3 - 12*a)/(a**6 + 3*a**4 + 3*a**2 + 1)
#        c4 [exact=OK sympy=OK]  gt=(-12*a**4 + 72*a**2 - 12)/(a**8 + 4*a**6 + 6*a**4 + 4*a**2 + 1)  pred=(-12*a**4 + 72*a**2 - 12)/(a**8 + 4*a**6 + 6*a**4 + 4*a**2 + 1)
#        => exact: 5/5  sympy: 5/5
#
#   [ 9] f(x) = x*log(1 + x)
#        c0 [exact=OK sympy=OK]  gt=a*log(a + 1)  pred=a*log(a + 1)
#        c1 [exact=OK sympy=OK]  gt=(a*log(a + 1) + a + log(a + 1))/(a + 1)  pred=(a*log(a + 1) + a + log(a + 1))/(a + 1)
#        c2 [exact=OK sympy=OK]  gt=(a + 2)/(a**2 + 2*a + 1)  pred=(a + 2)/(a**2 + 2*a + 1)
#        c3 [exact=OK sympy=OK]  gt=(-a - 3)/(a**3 + 3*a**2 + 3*a + 1)  pred=(-a - 3)/(a**3 + 3*a**2 + 3*a + 1)
#        c4 [exact=OK sympy=OK]  gt=(2*a + 8)/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)  pred=(2*a + 8)/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)
#        => exact: 5/5  sympy: 5/5
#
#   [10] f(x) = x/(1 - x)
#        c0 [exact=OK sympy=OK]  gt=-a/(a - 1)  pred=-a/(a - 1)
#        c1 [exact=OK sympy=OK]  gt=1/(a**2 - 2*a + 1)  pred=1/(a**2 - 2*a + 1)
#        c2 [exact=OK sympy=OK]  gt=-2/(a**3 - 3*a**2 + 3*a - 1)  pred=-2/(a**3 - 3*a**2 + 3*a - 1)
#        c3 [exact=OK sympy=OK]  gt=6/(a**4 - 4*a**3 + 6*a**2 - 4*a + 1)  pred=6/(a**4 - 4*a**3 + 6*a**2 - 4*a + 1)
#        c4 [exact=OK sympy=OK]  gt=-24/(a**5 - 5*a**4 + 10*a**3 - 10*a**2 + 5*a - 1)  pred=-24/(a**5 - 5*a**4 + 10*a**3 - 10*a**2 + 5*a - 1)
#        => exact: 5/5  sympy: 5/5
#
#   [11] f(x) = x/(1 + x)
#        c0 [exact=OK sympy=OK]  gt=a/(a + 1)  pred=a/(a + 1)
#        c1 [exact=OK sympy=OK]  gt=1/(a**2 + 2*a + 1)  pred=1/(a**2 + 2*a + 1)
#        c2 [exact=OK sympy=OK]  gt=-2/(a**3 + 3*a**2 + 3*a + 1)  pred=-2/(a**3 + 3*a**2 + 3*a + 1)
#        c3 [exact=OK sympy=OK]  gt=6/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)  pred=6/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)
#        c4 [exact=OK sympy=OK]  gt=-24/(a**5 + 5*a**4 + 10*a**3 + 10*a**2 + 5*a + 1)  pred=-24/(a**5 + 5*a**4 + 10*a**3 + 10*a**2 + 5*a + 1)
#        => exact: 5/5  sympy: 5/5
#
#   [12] f(x) = 1/(1 + x**2)
#        c0 [exact=OK sympy=OK]  gt=1/(a**2 + 1)  pred=1/(a**2 + 1)
#        c1 [exact=OK sympy=OK]  gt=-2*a/(a**4 + 2*a**2 + 1)  pred=-2*a/(a**4 + 2*a**2 + 1)
#        c2 [exact=OK sympy=OK]  gt=(6*a**2 - 2)/(a**6 + 3*a**4 + 3*a**2 + 1)  pred=(6*a**2 - 2)/(a**6 + 3*a**4 + 3*a**2 + 1)
#        c3 [exact=OK sympy=OK]  gt=(-24*a**3 + 24*a)/(a**8 + 4*a**6 + 6*a**4 + 4*a**2 + 1)  pred=(-24*a**3 + 24*a)/(a**8 + 4*a**6 + 6*a**4 + 4*a**2 + 1)
#        c4 [exact=OK sympy=OK]  gt=(120*a**4 - 240*a**2 + 24)/(a**10 + 5*a**8 + 10*a**6 + 10*a**4 + 5*a**2 + 1)  pred=(120*a**4 - 240*a**2 + 24)/(a**10 + 5*a**8 + 10*a**6 + 10*a**4 + 5*a**2 + 1)
#        => exact: 5/5  sympy: 5/5
#
#   [13] f(x) = x**2/(1 - x)
#        c0 [exact=OK sympy=OK]  gt=-a**2/(a - 1)  pred=-a**2/(a - 1)
#        c1 [exact=OK sympy=OK]  gt=(-a**2 + 2*a)/(a**2 - 2*a + 1)  pred=(-a**2 + 2*a)/(a**2 - 2*a + 1)
#        c2 [exact=OK sympy=OK]  gt=-2/(a**3 - 3*a**2 + 3*a - 1)  pred=-2/(a**3 - 3*a**2 + 3*a - 1)
#        c3 [exact=OK sympy=OK]  gt=6/(a**4 - 4*a**3 + 6*a**2 - 4*a + 1)  pred=6/(a**4 - 4*a**3 + 6*a**2 - 4*a + 1)
#        c4 [exact=OK sympy=OK]  gt=-24/(a**5 - 5*a**4 + 10*a**3 - 10*a**2 + 5*a - 1)  pred=-24/(a**5 - 5*a**4 + 10*a**3 - 10*a**2 + 5*a - 1)
#        => exact: 5/5  sympy: 5/5
#
#   [14] f(x) = sin(x**2)
#        c0 [exact=OK sympy=OK]  gt=sin(a**2)  pred=sin(a**2)
#        c1 [exact=OK sympy=OK]  gt=2*a*cos(a**2)  pred=2*a*cos(a**2)
#        c2 [exact=OK sympy=OK]  gt=-4*a**2*sin(a**2) + 2*cos(a**2)  pred=-4*a**2*sin(a**2) + 2*cos(a**2)
#        c3 [exact=OK sympy=OK]  gt=-8*a**3*cos(a**2) - 12*a*sin(a**2)  pred=-8*a**3*cos(a**2) - 12*a*sin(a**2)
#        c4 [exact=OK sympy=OK]  gt=16*a**4*sin(a**2) - 48*a**2*cos(a**2) - 12*sin(a**2)  pred=16*a**4*sin(a**2) - 48*a**2*cos(a**2) - 12*sin(a**2)
#        => exact: 5/5  sympy: 5/5
#
#   [15] f(x) = exp(x**2)
#        c0 [exact=OK sympy=OK]  gt=exp(a**2)  pred=exp(a**2)
#        c1 [exact=OK sympy=OK]  gt=2*a*exp(a**2)  pred=2*a*exp(a**2)
#        c2 [exact=OK sympy=OK]  gt=4*a**2*exp(a**2) + 2*exp(a**2)  pred=4*a**2*exp(a**2) + 2*exp(a**2)
#        c3 [exact=OK sympy=OK]  gt=8*a**3*exp(a**2) + 12*a*exp(a**2)  pred=8*a**3*exp(a**2) + 12*a*exp(a**2)
#        c4 [exact=OK sympy=OK]  gt=16*a**4*exp(a**2) + 48*a**2*exp(a**2) + 12*exp(a**2)  pred=16*a**4*exp(a**2) + 48*a**2*exp(a**2) + 12*exp(a**2)
#        => exact: 5/5  sympy: 5/5
#
#   [16] f(x) = cos(sqrt(1 + x))
#        c0 [exact=OK sympy=OK]  gt=cos(sqrt(a + 1))  pred=cos(sqrt(a + 1))
#        c1 [exact=OK sympy=OK]  gt=-sin(sqrt(a + 1))/(2*sqrt(a + 1))  pred=-sin(sqrt(a + 1))/(2*sqrt(a + 1))
#        c2 [exact=OK sympy=OK]  gt=(-sqrt(a + 1)*cos(sqrt(a + 1)) + sin(sqrt(a + 1)))/(4*a*sqrt(a + 1) + 4*sqrt(a + 1))  pred=(-sqrt(a + 1)*cos(sqrt(a + 1)) + sin(sqrt(a + 1)))/(4*a*sqrt(a + 1) + 4*sqrt(a + 1))
#        c3 [exact=OK sympy=OK]  gt=(a*sqrt(a + 1)*sin(sqrt(a + 1)) + 3*a*cos(sqrt(a + 1)) - 2*sqrt(a + 1)*sin(sqrt(a + 1)) + 3*cos(sqrt(a + 1)))/(8*a**3 + 24*a**2 + 24*a + 8)  pred=(a*sqrt(a + 1)*sin(sqrt(a + 1)) + 3*a*cos(sqrt(a + 1)) - 2*sqrt(a + 1)*sin(sqrt(a + 1)) + 3*cos(sqrt(a + 1)))/(8*a**3 + 24*a**2 + 24*a + 8)
#        c4 [exact=OK sympy=OK]  gt=(a**2*cos(sqrt(a + 1)) - 6*a*sqrt(a + 1)*sin(sqrt(a + 1)) - 13*a*cos(sqrt(a + 1)) + 9*sqrt(a + 1)*sin(sqrt(a + 1)) - 14*cos(sqrt(a + 1)))/(16*a**4 + 64*a**3 + 96*a**2 + 64*a + 16)  pred=(a**2*cos(sqrt(a + 1)) - 6*a*sqrt(a + 1)*sin(sqrt(a + 1)) - 13*a*cos(sqrt(a + 1)) + 9*sqrt(a + 1)*sin(sqrt(a + 1)) - 14*cos(sqrt(a + 1)))/(16*a**4 + 64*a**3 + 96*a**2 + 64*a + 16)
#        => exact: 5/5  sympy: 5/5
#
#   [17] f(x) = log(1 + sin(x))
#        c0 [exact=OK sympy=OK]  gt=log(sin(a) + 1)  pred=log(sin(a) + 1)
#        c1 [exact=OK sympy=OK]  gt=cos(a)/(sin(a) + 1)  pred=cos(a)/(sin(a) + 1)
#        c2 [exact=OK sympy=OK]  gt=(-sin(a)**2 - sin(a) - cos(a)**2)/(sin(a)**2 + 2*sin(a) + 1)  pred=(-sin(a)**2 - sin(a) - cos(a)**2)/(sin(a)**2 + 2*sin(a) + 1)
#        c3 [exact=OK sympy=OK]  gt=(2*sin(a)**2*cos(a) + sin(a)*cos(a) + 2*cos(a)**3 - cos(a))/(sin(a)**3 + 3*sin(a)**2 + 3*sin(a) + 1)  pred=(2*sin(a)**2*cos(a) + sin(a)*cos(a) + 2*cos(a)**3 - cos(a))/(sin(a)**3 + 3*sin(a)**2 + 3*sin(a) + 1)
#        c4 [exact=OK sympy=OK]  gt=(-2*sin(a)**4 - 3*sin(a)**3 - 8*sin(a)**2*cos(a)**2 - 4*sin(a)*cos(a)**2 + sin(a) - 6*cos(a)**4 + 4*cos(a)**2)/(sin(a)**4 + 4*sin(a)**3 + 6*sin(a)**2 + 4*sin(a) + 1)  pred=(-2*sin(a)**4 - 3*sin(a)**3 - 8*sin(a)**2*cos(a)**2 - 4*sin(a)*cos(a)**2 + sin(a) - 6*cos(a)**4 + 4*cos(a)**2)/(sin(a)**4 + 4*sin(a)**3 + 6*sin(a)**2 + 4*sin(a) + 1)
#        => exact: 5/5  sympy: 5/5
#
#   [18] f(x) = (x + 1)*exp(x)
#        c0 [exact=OK sympy=OK]  gt=a*exp(a) + exp(a)  pred=a*exp(a) + exp(a)
#        c1 [exact=OK sympy=OK]  gt=a*exp(a) + 2*exp(a)  pred=a*exp(a) + 2*exp(a)
#        c2 [exact=OK sympy=OK]  gt=a*exp(a) + 3*exp(a)  pred=a*exp(a) + 3*exp(a)
#        c3 [exact=OK sympy=OK]  gt=a*exp(a) + 4*exp(a)  pred=a*exp(a) + 4*exp(a)
#        c4 [exact=OK sympy=OK]  gt=a*exp(a) + 5*exp(a)  pred=a*exp(a) + 5*exp(a)
#        => exact: 5/5  sympy: 5/5
#
#   [19] f(x) = x**2*log(1 + x)
#        c0 [exact=OK sympy=OK]  gt=a**2*log(a + 1)  pred=a**2*log(a + 1)
#        c1 [exact=OK sympy=OK]  gt=(2*a**2*log(a + 1) + a**2 + 2*a*log(a + 1))/(a + 1)  pred=(2*a**2*log(a + 1) + a**2 + 2*a*log(a + 1))/(a + 1)
#        c2 [exact=-- sympy=--]  gt=(2*a**2*log(a + 1) + 3*a**2 + 4*a*log(a + 1) + 4*a + 2*log(a + 1))/(a**2 + 2*a + 1)  pred=(2*a**2*log(a + 1) + 3*a**2 + 4*a*log(a + 1) + 4*log(a + 1))/(a**2 + 2*a + 1)
#        c3 [exact=OK sympy=OK]  gt=(2*a**2 + 6*a + 6)/(a**3 + 3*a**2 + 3*a + 1)  pred=(2*a**2 + 6*a + 6)/(a**3 + 3*a**2 + 3*a + 1)
#        c4 [exact=-- sympy=--]  gt=(-2*a**2 - 8*a - 12)/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)  pred=(-4*a**2 - 12)/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)
#        => exact: 3/5  sympy: 3/5
#
#   [20] f(x) = exp(x)*cos(x)
#        c0 [exact=OK sympy=OK]  gt=exp(a)*cos(a)  pred=exp(a)*cos(a)
#        c1 [exact=OK sympy=OK]  gt=-exp(a)*sin(a) + exp(a)*cos(a)  pred=-exp(a)*sin(a) + exp(a)*cos(a)
#        c2 [exact=OK sympy=OK]  gt=-2*exp(a)*sin(a)  pred=-2*exp(a)*sin(a)
#        c3 [exact=OK sympy=OK]  gt=-2*exp(a)*sin(a) - 2*exp(a)*cos(a)  pred=-2*exp(a)*sin(a) - 2*exp(a)*cos(a)
#        c4 [exact=OK sympy=OK]  gt=-4*exp(a)*cos(a)  pred=-4*exp(a)*cos(a)
#        => exact: 5/5  sympy: 5/5
#
#   [21] f(x) = exp(x)*(x**2 + 1)
#        c0 [exact=OK sympy=OK]  gt=a**2*exp(a) + exp(a)  pred=a**2*exp(a) + exp(a)
#        c1 [exact=OK sympy=OK]  gt=a**2*exp(a) + 2*a*exp(a) + exp(a)  pred=a**2*exp(a) + 2*a*exp(a) + exp(a)
#        c2 [exact=OK sympy=OK]  gt=a**2*exp(a) + 4*a*exp(a) + 3*exp(a)  pred=a**2*exp(a) + 4*a*exp(a) + 3*exp(a)
#        c3 [exact=OK sympy=OK]  gt=a**2*exp(a) + 6*a*exp(a) + 7*exp(a)  pred=a**2*exp(a) + 6*a*exp(a) + 7*exp(a)
#        c4 [exact=OK sympy=OK]  gt=a**2*exp(a) + 8*a*exp(a) + 13*exp(a)  pred=a**2*exp(a) + 8*a*exp(a) + 13*exp(a)
#        => exact: 5/5  sympy: 5/5
#
#   [22] f(x) = sin(x)*cos(x)
#        c0 [exact=OK sympy=OK]  gt=sin(a)*cos(a)  pred=sin(a)*cos(a)
#        c1 [exact=OK sympy=OK]  gt=-sin(a)**2 + cos(a)**2  pred=-sin(a)**2 + cos(a)**2
#        c2 [exact=OK sympy=OK]  gt=-4*sin(a)*cos(a)  pred=-4*sin(a)*cos(a)
#        c3 [exact=OK sympy=OK]  gt=4*sin(a)**2 - 4*cos(a)**2  pred=4*sin(a)**2 - 4*cos(a)**2
#        c4 [exact=OK sympy=OK]  gt=16*sin(a)*cos(a)  pred=16*sin(a)*cos(a)
#        => exact: 5/5  sympy: 5/5
#
#   [23] f(x) = log(1 + x**3)
#        c0 [exact=OK sympy=OK]  gt=log(a**3 + 1)  pred=log(a**3 + 1)
#        c1 [exact=OK sympy=OK]  gt=3*a**2/(a**3 + 1)  pred=3*a**2/(a**3 + 1)
#        c2 [exact=OK sympy=OK]  gt=(-3*a**4 + 6*a)/(a**6 + 2*a**3 + 1)  pred=(-3*a**4 + 6*a)/(a**6 + 2*a**3 + 1)
#        c3 [exact=OK sympy=OK]  gt=(6*a**6 - 42*a**3 + 6)/(a**9 + 3*a**6 + 3*a**3 + 1)  pred=(6*a**6 - 42*a**3 + 6)/(a**9 + 3*a**6 + 3*a**3 + 1)
#        c4 [exact=OK sympy=OK]  gt=(-18*a**8 + 288*a**5 - 180*a**2)/(a**12 + 4*a**9 + 6*a**6 + 4*a**3 + 1)  pred=(-18*a**8 + 288*a**5 - 180*a**2)/(a**12 + 4*a**9 + 6*a**6 + 4*a**3 + 1)
#        => exact: 5/5  sympy: 5/5
#
#   [24] f(x) = log(1 + x)*cos(x)
#        c0 [exact=OK sympy=OK]  gt=log(a + 1)*cos(a)  pred=log(a + 1)*cos(a)
#        c1 [exact=OK sympy=OK]  gt=(-a*log(a + 1)*sin(a) - log(a + 1)*sin(a) + cos(a))/(a + 1)  pred=(-a*log(a + 1)*sin(a) - log(a + 1)*sin(a) + cos(a))/(a + 1)
#        c2 [exact=OK sympy=OK]  gt=(-a**2*log(a + 1)*cos(a) - 2*a*log(a + 1)*cos(a) - 2*a*sin(a) - log(a + 1)*cos(a) - 2*sin(a) - cos(a))/(a**2 + 2*a + 1)  pred=(-a**2*log(a + 1)*cos(a) - 2*a*log(a + 1)*cos(a) - 2*a*sin(a) - log(a + 1)*cos(a) - 2*sin(a) - cos(a))/(a**2 + 2*a + 1)
#        c3 [exact=-- sympy=--]  gt=(a**3*log(a + 1)*sin(a) + 3*a**2*log(a + 1)*sin(a) - 3*a**2*cos(a) + 3*a*log(a + 1)*sin(a) + 3*a*sin(a) - 6*a*cos(a) + log(a + 1)*sin(a) + 3*sin(a) - cos(a))/(a**3 + 3*a**2 + 3*a + 1)  pred=(a**3*log(a + 1)*sin(a) + 6*a**2*log(a + 1)*sin(a) - 3*a**2*cos(a) - 3*a*sin(a) + 3*a*cos(a) + log(a + 1)*cos(a) + 3*sin(a) - cos(a))/(a**3 + 3*a**2 + 3*a + 1)
#        c4 [exact=-- sympy=--]  gt=(a**4*log(a + 1)*cos(a) + 4*a**3*log(a + 1)*cos(a) + 4*a**3*sin(a) + 6*a**2*log(a + 1)*cos(a) + 12*a**2*sin(a) + 6*a**2*cos(a) + 4*a*log(a + 1)*cos(a) + 4*a*sin(a) + 12*a*cos(a) + log(a + 1)*cos(a) - 4*sin(a))/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)  pred=(a**4*log(a + 1)*cos(a) + 4*a**3*log(a + 1)*cos(a) + 4*a**3*sin(a) + 6*a**2*log(a + 1)*cos(a) - 12*a**2*sin(a) + 6*a**2*cos(a) + 4*a*log(a + 1)*cos(a) + 4*a*sin(a) - 12*a*cos(a) - 10*cos(a) + 1)/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)
#        => exact: 3/5  sympy: 3/5
#
#   [25] f(x) = x*exp(x)*sin(x)
#        c0 [exact=OK sympy=OK]  gt=a*exp(a)*sin(a)  pred=a*exp(a)*sin(a)
#        c1 [exact=OK sympy=OK]  gt=a*exp(a)*sin(a) + a*exp(a)*cos(a) + exp(a)*sin(a)  pred=a*exp(a)*sin(a) + a*exp(a)*cos(a) + exp(a)*sin(a)
#        c2 [exact=OK sympy=OK]  gt=2*a*exp(a)*cos(a) + 2*exp(a)*sin(a) + 2*exp(a)*cos(a)  pred=2*a*exp(a)*cos(a) + 2*exp(a)*sin(a) + 2*exp(a)*cos(a)
#        c3 [exact=OK sympy=OK]  gt=-2*a*exp(a)*sin(a) + 2*a*exp(a)*cos(a) + 6*exp(a)*cos(a)  pred=-2*a*exp(a)*sin(a) + 2*a*exp(a)*cos(a) + 6*exp(a)*cos(a)
#        c4 [exact=-- sympy=--]  gt=-4*a*exp(a)*sin(a) - 8*exp(a)*sin(a) + 8*exp(a)*cos(a)  pred=-8*exp(a)*sin(a) + 8*exp(a)*cos(a)
#        => exact: 4/5  sympy: 4/5
#
#   [26] f(x) = x*exp(x)*cos(x)
#        c0 [exact=OK sympy=OK]  gt=a*exp(a)*cos(a)  pred=a*exp(a)*cos(a)
#        c1 [exact=OK sympy=OK]  gt=-a*exp(a)*sin(a) + a*exp(a)*cos(a) + exp(a)*cos(a)  pred=-a*exp(a)*sin(a) + a*exp(a)*cos(a) + exp(a)*cos(a)
#        c2 [exact=OK sympy=OK]  gt=-2*a*exp(a)*sin(a) - 2*exp(a)*sin(a) + 2*exp(a)*cos(a)  pred=-2*a*exp(a)*sin(a) - 2*exp(a)*sin(a) + 2*exp(a)*cos(a)
#        c3 [exact=OK sympy=OK]  gt=-2*a*exp(a)*sin(a) - 2*a*exp(a)*cos(a) - 6*exp(a)*sin(a)  pred=-2*a*exp(a)*sin(a) - 2*a*exp(a)*cos(a) - 6*exp(a)*sin(a)
#        c4 [exact=OK sympy=OK]  gt=-4*a*exp(a)*cos(a) - 8*exp(a)*sin(a) - 8*exp(a)*cos(a)  pred=-4*a*exp(a)*cos(a) - 8*exp(a)*sin(a) - 8*exp(a)*cos(a)
#        => exact: 5/5  sympy: 5/5
#
#   [27] f(x) = sqrt(1 + x)*sin(x)
#        c0 [exact=OK sympy=OK]  gt=sqrt(a + 1)*sin(a)  pred=sqrt(a + 1)*sin(a)
#        c1 [exact=OK sympy=OK]  gt=(2*a*cos(a) + sin(a) + 2*cos(a))/(2*sqrt(a + 1))  pred=(2*a*cos(a) + sin(a) + 2*cos(a))/(2*sqrt(a + 1))
#        c2 [exact=OK sympy=OK]  gt=(-4*a**2*sqrt(a + 1)*sin(a) - 8*a*sqrt(a + 1)*sin(a) + 4*a*sqrt(a + 1)*cos(a) - 5*sqrt(a + 1)*sin(a) + 4*sqrt(a + 1)*cos(a))/(4*a**2 + 8*a + 4)  pred=(-4*a**2*sqrt(a + 1)*sin(a) - 8*a*sqrt(a + 1)*sin(a) + 4*a*sqrt(a + 1)*cos(a) - 5*sqrt(a + 1)*sin(a) + 4*sqrt(a + 1)*cos(a))/(4*a**2 + 8*a + 4)
#        c3 [exact=-- sympy=--]  gt=(-8*a**3*cos(a) - 12*a**2*sin(a) - 24*a**2*cos(a) - 24*a*sin(a) - 30*a*cos(a) - 9*sin(a) - 14*cos(a))/(8*a**2*sqrt(a + 1) + 16*a*sqrt(a + 1) + 8*sqrt(a + 1))  pred=(-24*a**3*sin(a) - 32*a**2*cos(a) - 24*a*cos(a) - 3*sin(a) - 4*cos(a))/(8*a**2*sqrt(a + 1) + 16*a*sqrt(a + 1) + 8*sqrt(a + 1))
#        c4 [exact=-- sympy=--]  gt=(16*a**4*sqrt(a + 1)*sin(a) + 64*a**3*sqrt(a + 1)*sin(a) - 32*a**3*sqrt(a + 1)*cos(a) + 120*a**2*sqrt(a + 1)*sin(a) - 96*a**2*sqrt(a + 1)*cos(a) + 112*a*sqrt(a + 1)*sin(a) - 72*a*sqrt(a + 1)*cos(a) + 25*sqrt(a + 1)*sin(a) - 8*sqrt(a + 1)*cos(a))/(16*a**4 + 64*a**3 + 96*a**2 + 64*a + 16)  pred=(-16*a**4*sqrt(a + 1)*sin(a) - 16*a**3*sqrt(a + 1)*sin(a) + 48*a**2*sqrt(a + 1)*sin(a) - 72*a**2*sqrt(a + 1)*cos(a) - 24*a*sqrt(a + 1)*sin(a) + 16*sqrt(a + 1)*sin(a) - 25*sqrt(a + 1)*cos(a))/(16*a**4 + 64*a**3 + 96*a**2 + 64*a + 16)
#        => exact: 3/5  sympy: 3/5
#
#   [28] f(x) = sqrt(1 + x)/(1 + x)
#        c0 [exact=OK sympy=OK]  gt=1/sqrt(a + 1)  pred=1/sqrt(a + 1)
#        c1 [exact=OK sympy=OK]  gt=-1/(2*a*sqrt(a + 1) + 2*sqrt(a + 1))  pred=-1/(2*a*sqrt(a + 1) + 2*sqrt(a + 1))
#        c2 [exact=OK sympy=OK]  gt=3/(4*a**2*sqrt(a + 1) + 8*a*sqrt(a + 1) + 4*sqrt(a + 1))  pred=3/(4*a**2*sqrt(a + 1) + 8*a*sqrt(a + 1) + 4*sqrt(a + 1))
#        c3 [exact=OK sympy=OK]  gt=-15/(8*a**3*sqrt(a + 1) + 24*a**2*sqrt(a + 1) + 24*a*sqrt(a + 1) + 8*sqrt(a + 1))  pred=-15/(8*a**3*sqrt(a + 1) + 24*a**2*sqrt(a + 1) + 24*a*sqrt(a + 1) + 8*sqrt(a + 1))
#        c4 [exact=OK sympy=OK]  gt=105/(16*a**4*sqrt(a + 1) + 64*a**3*sqrt(a + 1) + 96*a**2*sqrt(a + 1) + 64*a*sqrt(a + 1) + 16*sqrt(a + 1))  pred=105/(16*a**4*sqrt(a + 1) + 64*a**3*sqrt(a + 1) + 96*a**2*sqrt(a + 1) + 64*a*sqrt(a + 1) + 16*sqrt(a + 1))
#        => exact: 5/5  sympy: 5/5
#
#   [29] f(x) = cos(x)/(1 + x)
#        c0 [exact=OK sympy=OK]  gt=cos(a)/(a + 1)  pred=cos(a)/(a + 1)
#        c1 [exact=OK sympy=OK]  gt=(-a*sin(a) - sin(a) - cos(a))/(a**2 + 2*a + 1)  pred=(-a*sin(a) - sin(a) - cos(a))/(a**2 + 2*a + 1)
#        c2 [exact=OK sympy=OK]  gt=(-a**2*cos(a) + 2*a*sin(a) - 2*a*cos(a) + 2*sin(a) + cos(a))/(a**3 + 3*a**2 + 3*a + 1)  pred=(-a**2*cos(a) + 2*a*sin(a) - 2*a*cos(a) + 2*sin(a) + cos(a))/(a**3 + 3*a**2 + 3*a + 1)
#        c3 [exact=OK sympy=OK]  gt=(a**3*sin(a) + 3*a**2*sin(a) + 3*a**2*cos(a) - 3*a*sin(a) + 6*a*cos(a) - 5*sin(a) - 3*cos(a))/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)  pred=(a**3*sin(a) + 3*a**2*sin(a) + 3*a**2*cos(a) - 3*a*sin(a) + 6*a*cos(a) - 5*sin(a) - 3*cos(a))/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)
#        c4 [exact=OK sympy=OK]  gt=(a**4*cos(a) - 4*a**3*sin(a) + 4*a**3*cos(a) - 12*a**2*sin(a) - 6*a**2*cos(a) + 12*a*sin(a) - 20*a*cos(a) + 20*sin(a) + 13*cos(a))/(a**5 + 5*a**4 + 10*a**3 + 10*a**2 + 5*a + 1)  pred=(a**4*cos(a) - 4*a**3*sin(a) + 4*a**3*cos(a) - 12*a**2*sin(a) - 6*a**2*cos(a) + 12*a*sin(a) - 20*a*cos(a) + 20*sin(a) + 13*cos(a))/(a**5 + 5*a**4 + 10*a**3 + 10*a**2 + 5*a + 1)
#        => exact: 5/5  sympy: 5/5
#
#   [30] f(x) = exp(x)/(1 + x)
#        c0 [exact=OK sympy=OK]  gt=exp(a)/(a + 1)  pred=exp(a)/(a + 1)
#        c1 [exact=-- sympy=--]  gt=a*exp(a)/(a**2 + 2*a + 1)  pred=(a*exp(a) + exp(a))/(a**2 + 2*a + 1)
#        c2 [exact=-- sympy=--]  gt=(a**2*exp(a) + exp(a))/(a**3 + 3*a**2 + 3*a + 1)  pred=(a**2*exp(a) + 2*a*exp(a) - 2*exp(a))/(a**3 + 3*a**2 + 3*a + 1)
#        c3 [exact=-- sympy=--]  gt=(a**3*exp(a) + 3*a*exp(a) - 2*exp(a))/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)  pred=(a**3*exp(a) + 3*a**2*exp(a) - 3*a*exp(a) + 3*exp(a))/(a**4 + 4*a**3 + 6*a**2 + 4*a + 1)
#        c4 [exact=-- sympy=--]  gt=(a**4*exp(a) + 6*a**2*exp(a) - 8*a*exp(a) + 9*exp(a))/(a**5 + 5*a**4 + 10*a**3 + 10*a**2 + 5*a + 1)  pred=(a**4*exp(a) + 4*a**3*exp(a) + 6*a**2*exp(a) - 8*a*exp(a) - 8*exp(a))/(a**5 + 5*a**4 + 10*a**3 + 10*a**2 + 5*a + 1)
#        => exact: 1/5  sympy: 1/5
#
#   Result: exact=22/30 (73.3%)  sympy=22/30 (73.3%)
# ====================================================================
#
#   Generating report in reports/transformer_20260312_135140/ ...
#   Report complete: reports/transformer_20260312_135140/
#
#   Report saved to reports/transformer_20260312_135140/
#   All tables and figures generated successfully.
